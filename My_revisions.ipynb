# %%
def max(a,b):
    if a>b:
        return a
    else:
        return b

# %%
max(19,12)
# Out:
# 19

# %%
def min (a,b):
    if a<b:
        return a
    else:
        return b

# %%
min(12,34)
# Out:
# 12

# %%
def even_or_odd(n):
    if n%2==0:
        return "even"
    else:
        return "odd"

# %%
even_or_odd(12)
# Out:
# 'even'

# %%
even_or_odd(19)
# Out:
# 'odd'

# %%
digit1=int(input("Enter a number"))
digit2=int(input("Enter a number"))
total=digit1+digit2
print("The sum of the digits is:",total)
# Out:
# Enter a number23
# Enter a number23
# The sum of the digits is: 46

# %%
digit1=int(input("Enter the number"))
digit2=int(input("Enter the  number"))
digit3=int(input("Enter the number"))
Avarage=(digit1+digit2+digit3)/3
print(Avarage)
# Out:
# Enter the number34
# Enter the  number23
# Enter the number45
# 34.0

# %%
def average(a,b,c):
    total=a+b+c
    return total/3

# %%
average(3,4,5)
# Out:
# 4.0

# %%
char=input("Enter a single letter:")
if char in 'aeiouAEIOU':
    print(char,"is a vowel")
else:
    print(char,"is a consonant")
# Out:
# Enter a single letter:w
# w is a consonant

# %%
char=input("Enter a letter")
if char in 'aeiouAEIOU':
    print(char, "is a vowel")
else:
    print(char, "is a consontant")
# Out:
# Enter a letterr
# r is a consontant

# %%
def con(a,b):
    return(a+b)

# %%
con("evans","kiplagat")
# Out:
# 'evanskiplagat'

# %%
text=input("Enter a number")
if text==text[::-1]:
    print("The string is palidrome")
else:
    print("The string is not palidrome")
# Out:
# Enter a numbermum
# The string is palidrome

# %%
def text():
    if text==text[::-1]:
        return("The string is palidrome")
    else:
        return("The string is not palidrone")

# %%
text("mum")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 text("mum")
#
# TypeError: text() takes 0 positional arguments but 1 was given

# %%
def factorial(n):
    if n<0:
        raise valueError("factorialis not define for negative numbers")
    result=1
    for i in range(1,n+1):
        result *=i
    return result

# %%
factorial(5)
# Out:
# 120

# %%
factorial(6)
# Out:
# 720

# %%
def power(base**exp):
    return base,exp
# Out:
#   Cell In [29], line 1
#     def power(base**exp):
#                   ^
# SyntaxError: invalid syntax

# %%
power(5,2)
# Out:
# (5, 2)
